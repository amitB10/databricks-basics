-- %% [markdown]
-- delta table
-- table in schema+ (metadata(parquet+delta_log))
--
-- Two types of table
--
-- 1. managed table (metadata(parquet+delta_log)) is stored in default location( databricks managed)
-- 2. unmanaged/ External table (metadata(parquet+delta_log)) is managed by user

-- %% [markdown]
-- create table dev.amitb10.sales_ext(id int) location '<you location>'

-- %%
create table dev.amitb10.sales_ext(id int) location 's3://jpmdatabricks/externaltable/amit/sales'

-- %%
insert into dev.amitb10.sales_ext values(1), (2)

-- %%
select * from dev.amitb10.sales_ext
