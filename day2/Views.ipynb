-- %% [markdown]
-- View:
-- (Virtual table)
-- - Standard View-- persited (SQL)
-- - temp view--- temp (sql) or pyspark

-- %%
create table dev.amitb10.nifty50_stocks as (select * from dev.naval.nifty_stock);

-- %%
select * from dev.amitb10.nifty50_stocks;

-- %%
select * from dev.amitb10.nifty50_stocks;

-- %%
create or replace view dev.amitb10.stock_industry_mCap as 
(select Industry, count(*) as count from dev.amitb10.nifty50_stocks group by all);

-- %%
use catalog dev;
show views in amitb10

-- %%
%python
superStore=spark.read.csv("s3://jpmdatabricks/metadata/super_store.csv",header=True,inferSchema=True)

-- %%
%python
superStore.display()
