# %%
# %sql
use catalog dev;

# %%
# %python
df=spark.table("dev.amitb10_bronze.transactions")
dffinal=df.dropDuplicates().drop("_rescued_data","ingestion_date").dropna()
dffinal.write.mode("overwrite").saveAsTable("dev.amitb10_silver.transaction")

# %%
# %sql
select * from dev.amitb10_silver.transaction limit 10;

# %%
# %python
df=spark.table("dev.amitb10_bronze.account_info")
dffinal=df.dropDuplicates().dropna()
dffinal.write.mode("overwrite").saveAsTable("dev.amitb10_silver.account_info")

# %%
# %sql
select * from dev.amitb10_silver.account_info limit 5;

# %%
# %python
df=spark.table("dev.amitb10_bronze.customer_profile")
dffinal=df.dropDuplicates().dropna()
dffinal.write.mode("overwrite").saveAsTable("dev.amitb10_silver.customer_profile")

# %%
# %sql
select * from dev.amitb10_silver.customer_profile limit 5;
