# %%
# %sql
create schema if not exists dev.amitb10_bronze;
create schema if not exists dev.amitb10_silver;
create schema if not exists dev.amitb10_gold;

# %%
# %python
input_path="/Volumes/dev/naval/raw"

# %%
def add_ingestion(df):
    df1=df.withColumn("ingestion_date",current_date())
    return df1
