-- %%
%python
Using below ways we can create Delta
1. SQL
2. Python
3. Dataframe


Internal of delta
1. parquet (data)
2. _delta_log(metadata)
    i. crc
    ii. json
    iii. checkpoint parquet file

-- %%
%sql
create table if not exists dev.amitb10.delta_test_table(id int, name string)

-- %%
%sql
describe extended dev.amitb10.delta_test_table

-- %%
%sql
describe detail dev.amitb10.delta_test_table

-- %%
%sql
describe history dev.amitb10.delta_test_table

-- %%
%sql
insert into dev.amitb10.delta_test_table values(1,'a'),(2,'c'),(3,'d')

-- %%
%sql
select * from dev.amitb10.delta_test_table

-- %%
describe dev.amitb10.delta_test_table;

-- %%
delete from dev.amitb10.delta_test_table where id = 1;

-- %%
insert into dev.amitb10.delta_test_table values(5,'k'),(10,'l'),(15,'m')

-- %%
select * from dev.amitb10.delta_test_table version as of 2

-- %%
select * from dev.amitb10.delta_test_table;

-- %%
describe history dev.amitb10.delta_test_table

-- %%
select * from dev.amitb10.delta_test_table timestamp as of '2025-04-08T06:58:05.000+00:00'

-- %%
describe detail dev.amitb10.delta_test_table

-- %%
optimize dev.amitb10.delta_test_table
zorder by(id)

-- %%
describe detail dev.amitb10.delta_test_table

-- %%
VACUUM dev.amitb10.delta_test_table RETAIN 168 HOURS

-- %%
VACUUM dev.amitb10.delta_test_table RETAIN 0 HOURS
