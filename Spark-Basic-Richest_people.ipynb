# %%
spark

# %%
data = spark.read.csv("/Volumes/dev/naval/raw/1000_richest_people_in_the_world.csv", header=True, inferSchema=True)
data.display()

# %%
import pyspark.sql.functions as F
from pyspark.sql.functions import col

# %%
cleanData = data.select(col())

# %%
dataWithCorrectName = data.withColumnRenamed("Net Worth (in billions)", "NetWorth")

# %%
dataWithCorrectName.write.saveAsTable("dev.amitb10.Amit_Richest_people")
