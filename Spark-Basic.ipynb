# %%
spark

# %%
data = spark.read.csv("/Volumes/dev/naval/raw/Spotify_Songs.csv", header=True, inferSchema=True)
data.show(10, False)

# %%
data.display()

# %%
data.filter("song_id < 10").display()

# %%
data1 = data.filter("song_id < 10")

# %%
data1.write.saveAsTable("dev.amitb10.Amit_Songs")
